# %%
res = []
for line in open('germany.txt', 'r'):
    item = line.split()
    ar = ""
    for i in range(6,len(item)-1):
        ar = ar + item[i]
    v = [item[0], item[1], item[2], item[3], item[4], item[5], ar, item[-1]]
    res.append(v)
data = pd.DataFrame(res)
data.to_csv('germany.csv', sep = ';', header=False, index=False, index_label=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
writer = pd.ExcelWriter('germany.xlsx', engine='xlsxwriter')
data.to_excel(writer, sheet_name='Sheet1')

# %%
line
# Out:
# '15931 20171001 20171004            116     52.0507   10.6362 Bor?um-Seinstedt                         Niedersachsen                                                                                     \n'

# %%
data
# Out:
#          0         1         2     3        4        5   \
# 0     00001  19120101  19860630   478  47.8413   8.8493
# 1     00002  19510101  20061231   138  50.8066   6.0996
# 2     00003  18910101  20110331   202  50.7827   6.0941
# 3     00004  19510101  19791031   243  50.7683   6.1207
# 4     00006  19821101  20171004   456  48.8359  10.0597
# 5     00007  19510101  19960131   473  48.8140  10.1285
# 6     00008  19310101  19911231   307  50.2546   8.1310
# 7     00009  19920601  20101231   200  50.2655   8.0516
# 8     00010  19610101  20050831   378  48.8857  12.1079
# 9     00012  19410101  20061231    61  52.3814  10.1860
# 10    00013  19910101  20061231   300  51.6154  11.2892
# 11    00014  19510101  19601230     9  53.5333   7.5000
# 12    00015  19510101  20170731   390  49.2346  10.9668
# 13    00016  19410101  19991231   370  49.2193  10.8845
# 14    00017  19510101  20091031   380  48.8421  11.8194
# 15    00018  19310101  19651230   420  49.6500   7.0833
# ...
